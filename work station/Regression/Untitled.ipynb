# %%
import pandas as pd

# %%
df = pd.read_csv('HouseSale.csv')

# %%
df
# Out:
#      _________  ____________ ____________.1  ________ (__)  zone Rating  \
# 0         50.3             5              2              8            1
# 1         50.9             2              1             21            1
# 2         53.4             3              1             10            1
# 3         56.4             5              3              8            1
# 4         56.6             1              3             16            1
# ..         ...           ...            ...            ...          ...
# 356      497.4             5              2             26            5
# 357      499.5             3              2             19            5
# 358      499.6             1              3             12            5
# 359      499.6             5              1             23            5
# 360  _________  ____________   ____________  ________ (__)  zone Rating
#
#     _______ (USD)
# 0          206042
# 1          179398
# 2          187509
# 3          242866
# 4          158455
# ..            ...
# 356       1107045
# 357       1092027
# 358       1102534
# 359       1070454
# 360         price
#
# [361 rows x 6 columns]

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [_________, ____________, ____________.1, ________ (__), zone Rating, _______ (USD)]
# Index: []

# %%
df.info
# Out:
# <bound method DataFrame.info of      _________  ____________ ____________.1  ________ (__)  zone Rating  \
# 0         50.3             5              2              8            1
# 1         50.9             2              1             21            1
# 2         53.4             3              1             10            1
# 3         56.4             5              3              8            1
# 4         56.6             1              3             16            1
# ..         ...           ...            ...            ...          ...
# 356      497.4             5              2             26            5
# 357      499.5             3              2             19            5
# 358      499.6             1              3             12            5
# 359      499.6             5              1             23            5
# 360  _________  ____________   ____________  ________ (__)  zone Rating
#
#     _______ (USD)
# 0          206042
# 1          179398
# 2          187509
# 3          242866
# 4          158455
# ..            ...
# 356       1107045
# 357       1092027
# 358       1102534
# 359       1070454
# 360         price
#
# [361 rows x 6 columns]>

# %%
df.isna().sum()
# Out:
# _________         0
# ____________      0
# ____________.1    0
# ________ (__)     0
# zone Rating       0
# _______ (USD)     0
# dtype: int64

# %%
df.columns = ['area', 'colB', 'colC', 'house_age', 'zone_rating', 'price_usd']

# %%
df
# Out:
#           area          colB          colC      house_age  zone_rating  \
# 0         50.3             5             2              8            1
# 1         50.9             2             1             21            1
# 2         53.4             3             1             10            1
# 3         56.4             5             3              8            1
# 4         56.6             1             3             16            1
# ..         ...           ...           ...            ...          ...
# 356      497.4             5             2             26            5
# 357      499.5             3             2             19            5
# 358      499.6             1             3             12            5
# 359      499.6             5             1             23            5
# 360  _________  ____________  ____________  ________ (__)  zone Rating
#
#     price_usd
# 0      206042
# 1      179398
# 2      187509
# 3      242866
# 4      158455
# ..        ...
# 356   1107045
# 357   1092027
# 358   1102534
# 359   1070454
# 360     price
#
# [361 rows x 6 columns]

# %%
df = df.drop(360)

# %%
import seaborn as sns

# %%
sns.catplot(df, x='zone_rating', y='price_usd', kind='boxen')

# %%
df = df.apply(pd.to_numeric)

# %%
df.to_csv('cleaned_house_sale.csv', index=False)
